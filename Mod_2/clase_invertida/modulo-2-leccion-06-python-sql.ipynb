# %% [markdown]
# # PAIR-modulo-2-leccion-13-python-sql

# %% [markdown]
#  1. Importa las librerías necesarias

# %%
import pandas as pd
import mysql.connector
from mysql.connector import errorcode

# %% [markdown]
# 2. Crea la conexión a la base de datos Northwind y devuelve un mensaje de error si algo no ocurre cómo debería

# %%
## intenta hacer la conexión son la base de datos de tienda 
try:
  cnx = mysql.connector.connect(user='root', password='AlumnaAdalab',
                              host='127.0.0.1',
                              database='northwind')
# en caso de que no lo consigas por que hay algún error entonces ...
except mysql.connector.Error as err:

  # si es un error con la contraseña devuelveme un mensaje de acceso denegado ya que tenemos problemas con la contraseña
  if err.errno == errorcode.ER_ACCESS_DENIED_ERROR:
    print("Something is wrong with your user name or password")
  
  # si el error no tiene que ver con la contraseña, puede ser porque la base de datos no exista, devuelveme un mensaje de que la base de datos no existe
  elif err.errno == errorcode.ER_BAD_DB_ERROR:
    print("Database does not exist")
  
  # si no es por ninguno de los errores anteriores, printeame cual es el error que estoy teniendo en mi conexión
  else:
    print(err)
else:
  cnx.close()

# %% [markdown]
# 3. Usando "information_schema", extrae los nombres de las columnas de la tabla "customers" de la BBDD "northwind

# %%
cnx = mysql.connector.connect(
  host="localhost",
  user="root",
  password="AlumnaAdalab",
  database="information_schema"
)

# iniciamos el cursor
mycursor = cnx.cursor()

# realizamos nuestra query
mycursor.execute("SELECT column_name FROM COLUMNS WHERE TABLE_NAME = 'customers' and table_schema = 'northwind'")

# le decimos a Python que nos devuelva todos los resultados de la query usando el método fetchall
myresult = mycursor.fetchall()
myresult
# Out:
# [('address',),
#  ('city',),
#  ('company_name',),
#  ('contact_name',),
#  ('contact_title',),
#  ('country',),
#  ('customer_id',),
#  ('fax',),
#  ('phone',),
#  ('postal_code',),
#  ('region',)]

# %% [markdown]
# 4. Selecciona todo de la tabla "customers" donde "country" sea "USA" o "Germany". Almacena los resultados en una variable.

# %%
cnx = mysql.connector.connect(
  host="localhost",
  user="root",
  password="AlumnaAdalab",
  database="northwind"
)

# iniciamos el cursor
mycursor = cnx.cursor()

# realizamos nuestra query
mycursor.execute("SELECT * FROM customers where country in ('USA', 'Germany')")

# le decimos a Python que nos devuelva todos los resultados de la query usando el método fetchall
myresult = mycursor.fetchall()
myresult
# Out:
# [('ALFKI',
#   'Alfreds Futterkiste',
#   'Maria Anders',
#   'Sales Representative',
#   'Obere Str. 57',
#   'Berlin',
#   '',
#   '12209',
#   'Germany',
#   '030-0074321',
#   '030-0076545'),
#  ('BLAUS',
#   'Blauer See Delikatessen',
#   'Hanna Moos',
#   'Sales Representative',
#   'Forsterstr. 57',
#   'Mannheim',
#   '',
#   '68306',
#   'Germany',
#   '0621-08460',
#   '0621-08924'),
#  ('DRACD',
#   'Drachenblut Delikatessen',
#   'Sven Ottlieb',
#   'Order Administrator',
#   'Walserweg 21',
#   'Aachen',
#   '',
#   '52066',
#   'Germany',
#   '0241-039123',
#   '0241-059428'),
#  ('FRANK',
#   'Frankenversand',
#   'Peter Franken',
#   'Marketing Manager',
#   'Berliner Platz 43',
#   'M?nchen',
#   '',
#   '80805',
#   'Germany',
#   '089-0877310',
#   '089-0877451'),
#  ('GREAL',
#   'Great Lakes Food Market',
#   'Howard Snyder',
#   'Marketing Manager',
#   '2732 Baker Blvd.',
#   'Eugene',
#   'OR',
#   '97403',
#   'USA',
#   '(503) 555-7555',
#   ''),
# ...

# %%
column_name = ['customer_id', 'company_name', 'contact_name', 'contact_title', 'address', 'city','region','postal_code','country','phone','fax']

# %% [markdown]
# 5. Convierte los resultados del ejercicio anterior en un Dataframe (no te olvides de poner el nombre a las coliumnas en el orden correcto)

# %%
df = pd.DataFrame(myresult, columns = column_name)

df.head()
# Out:
#   customer_id              company_name   contact_name         contact_title  \
# 0       ALFKI       Alfreds Futterkiste   Maria Anders  Sales Representative
# 1       BLAUS   Blauer See Delikatessen     Hanna Moos  Sales Representative
# 2       DRACD  Drachenblut Delikatessen   Sven Ottlieb   Order Administrator
# 3       FRANK            Frankenversand  Peter Franken     Marketing Manager
# 4       GREAL   Great Lakes Food Market  Howard Snyder     Marketing Manager
#
#              address      city region postal_code  country           phone  \
# 0      Obere Str. 57    Berlin              12209  Germany     030-0074321
# 1     Forsterstr. 57  Mannheim              68306  Germany      0621-08460
# 2       Walserweg 21    Aachen              52066  Germany     0241-039123
# 3  Berliner Platz 43   M?nchen              80805  Germany     089-0877310
# 4   2732 Baker Blvd.    Eugene     OR       97403      USA  (503) 555-7555
#
#            fax
# 0  030-0076545
# 1   0621-08924
# ...

# %% [markdown]
# 6. Muestra las 10 primeras filas del Dataframe y las 10 últimas:

# %%
df.head(10)
# Out:
#   customer_id                company_name    contact_name  \
# 0       ALFKI         Alfreds Futterkiste    Maria Anders
# 1       BLAUS     Blauer See Delikatessen      Hanna Moos
# 2       DRACD    Drachenblut Delikatessen    Sven Ottlieb
# 3       FRANK              Frankenversand   Peter Franken
# 4       GREAL     Great Lakes Food Market   Howard Snyder
# 5       HUNGC  Hungry Coyote Import Store   Yoshi Latimer
# 6       KOENE             K?niglich Essen   Philip Cramer
# 7       LAZYK        Lazy K Kountry Store      John Steel
# 8       LEHMS         Lehmanns Marktstand  Renate Messner
# 9       LETSS           Let's Stop N Shop    Jaime Yorres
#
#           contact_title                         address            city  \
# 0  Sales Representative                   Obere Str. 57          Berlin
# 1  Sales Representative                  Forsterstr. 57        Mannheim
# 2   Order Administrator                    Walserweg 21          Aachen
# ...

# %%
df.tail(10)
# Out:
#    customer_id                       company_name        contact_name  \
# 14       QUICK                         QUICK-Stop         Horst Kloss
# 15       RATTC         Rattlesnake Canyon Grocery        Paula Wilson
# 16       SAVEA                 Save-a-lot Markets      Jose Pavarotti
# 17       SPLIR              Split Rail Beer & Ale  Art Braunschweiger
# 18       THEBI                     The Big Cheese           Liz Nixon
# 19       THECR                    The Cracker Box            Liu Wong
# 20       TOMSP                 Toms Spezialit?ten       Karin Josephs
# 21       TRAIH  Trail's Head Gourmet Provisioners      Helvetius Nagy
# 22       WANDK                  Die Wandernde Kuh         Rita M?ller
# 23       WHITC               White Clover Markets      Karl Jablonski
#
#                      contact_title                      address         city  \
# 14              Accounting Manager             Taucherstra?e 10    Cunewalde
# ...

# %% [markdown]
# 7. Muestra 5 filas aleatorias del Dataframe

# %%
df.sample(10)
# Out:
#    customer_id              company_name         contact_name  \
# 11       MORGK    Morgenstern Gesundkost      Alexander Feuer
# 10       LONEP  Lonesome Pine Restaurant          Fran Wilson
# 20       TOMSP        Toms Spezialit?ten        Karin Josephs
# 0        ALFKI       Alfreds Futterkiste         Maria Anders
# 1        BLAUS   Blauer See Delikatessen           Hanna Moos
# 2        DRACD  Drachenblut Delikatessen         Sven Ottlieb
# 13       OTTIK        Ottilies K?seladen  Henriette Pfalzheim
# 16       SAVEA        Save-a-lot Markets       Jose Pavarotti
# 9        LETSS         Let's Stop N Shop         Jaime Yorres
# 7        LAZYK      Lazy K Kountry Store           John Steel
#
#            contact_title               address           city region  \
# 11   Marketing Assistant           Heerstr. 22        Leipzig
# 10         Sales Manager    89 Chiaroscuro Rd.       Portland     OR
# 20     Marketing Manager         Luisenstr. 48        M?nster
# ...

# %% [markdown]
# 8. ¿Hay nulos en el Dataframe?

# %%
df.isna().sum()
# Out:
# customer_id      0
# company_name     0
# contact_name     0
# contact_title    0
# address          0
# city             0
# region           0
# postal_code      0
# country          0
# phone            0
# fax              0
# dtype: int64

# %% [markdown]
# 9. Muestra los principales estadísticos:

# %%
df.describe().T
# Out:
#               count unique                   top freq
# customer_id      24     24                 ALFKI    1
# company_name     24     24   Alfreds Futterkiste    1
# contact_name     24     24          Maria Anders    1
# contact_title    24      9  Sales Representative    7
# address          24     24         Obere Str. 57    1
# city             24     23              Portland    2
# region           24      9                         11
# postal_code      24     24                 12209    1
# country          24      2                   USA   13
# phone            24     24           030-0074321    1
# fax              24     18                          7

# %% [markdown]
# 10. Muestra el nombre de las columnas del Dataframe:

# %%
df.columns
# Out:
# Index(['customer_id', 'company_name', 'contact_name', 'contact_title',
#        'address', 'city', 'region', 'postal_code', 'country', 'phone', 'fax'],
#       dtype='object')
