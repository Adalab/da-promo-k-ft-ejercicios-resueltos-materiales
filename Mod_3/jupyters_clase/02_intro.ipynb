# %% [markdown]
# # Intro Pandas
#
#
# - Series:
#     - son unidimensionales
#     - mismo tipo de dato
#     - tienen índice
#     - Caracteríaticas:
#         - .values -> nos devuelve los valores
#         - .size -> número total de elemntos
#
# - Dataframes:
#     - Crear DataFrames:
#
#     - loc/iloc:
#         - loc -> etiquetas
#         - iloc -> índices

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../files/rating-and-performance.csv", index_col=0)

df.head()
# Out:
#                                                    title  \
# index
# 0      2020 Summer Vintage Flamingo Print  Pajamas Se...
# 1      SSHOUSE Summer Casual Sleeveless Soirée Party ...
# 2      2020 Nouvelle Arrivée Femmes Printemps et Été ...
# 3      Hot Summer Cool T-shirt pour les femmes Mode T...
# 4      Femmes Shorts d'été à lacets taille élastique ...
#
#                                               title_orig  price  retail_price  \
# index
# 0      2020 Summer Vintage Flamingo Print  Pajamas Se...  16.00            14
# 1       Women's Casual Summer Sleeveless Sexy Mini Dress   8.00            22
# 2      2020 New Arrival Women Spring and Summer Beach...   8.00            43
# 3      Hot Summer Cool T Shirt for Women Fashion Tops...   8.00             8
# 4      Women Summer Shorts Lace Up Elastic Waistband ...   2.72             3
#
#       currency_buyer  units_sold  uses_ad_boosts  rating  rating_count  \
# index
# ...

# %%
# Extraer todas las filas de la columna "price"

df.loc[::, "price"]
# Out:
# index
# 0       16.00
# 1        8.00
# 2        8.00
# 3        8.00
# 4        2.72
#         ...
# 1568     6.00
# 1569     2.00
# 1570     5.00
# 1571    13.00
# 1572     7.00
# Name: price, Length: 1573, dtype: float64

# %%
list(df.columns).index("price")
# Out:
# 2

# %%
df.iloc[:, 2]
# Out:
# index
# 0       16.00
# 1        8.00
# 2        8.00
# 3        8.00
# 4        2.72
#         ...
# 1568     6.00
# 1569     2.00
# 1570     5.00
# 1571    13.00
# 1572     7.00
# Name: price, Length: 1573, dtype: float64

# %%
df.iloc[:, list(df.columns).index("price")]
# Out:
# index
# 0       16.00
# 1        8.00
# 2        8.00
# 3        8.00
# 4        2.72
#         ...
# 1568     6.00
# 1569     2.00
# 1570     5.00
# 1571    13.00
# 1572     7.00
# Name: price, Length: 1573, dtype: float64

# %%
df.shape
# Out:
# (1573, 43)

# %%
# Extraer todas las filas de las columnas "price" y "retail_price"
df_price = df.loc[::, ["price", "retail_price"]]

# %%
df_price.head()
# Out:
#        price  retail_price
# index
# 0      16.00            14
# 1       8.00            22
# 2       8.00            43
# 3       8.00             8
# 4       2.72             3

# %%
df.head(2)
# Out:
#                                                    title  \
# index
# 0      2020 Summer Vintage Flamingo Print  Pajamas Se...
# 1      SSHOUSE Summer Casual Sleeveless Soirée Party ...
#
#                                               title_orig  price  retail_price  \
# index
# 0      2020 Summer Vintage Flamingo Print  Pajamas Se...   16.0            14
# 1       Women's Casual Summer Sleeveless Sexy Mini Dress    8.0            22
#
#       currency_buyer  units_sold  uses_ad_boosts  rating  rating_count  \
# index
# 0                EUR         100               0    3.76            54
# 1                EUR       20000               1    3.45          6135
#
#        rating_five_count  ...  merchant_rating_count  merchant_rating  \
# index                     ...
# 0                   26.0  ...                    568         4.128521
# 1                 2269.0  ...                  17752         3.899673
#
#                     merchant_id  merchant_has_profile_picture  \
# ...

# %%
df.iloc[::, [2,3]]
# Out:
#        price  retail_price
# index
# 0      16.00            14
# 1       8.00            22
# 2       8.00            43
# 3       8.00             8
# 4       2.72             3
# ...      ...           ...
# 1568    6.00             9
# 1569    2.00            56
# 1570    5.00            19
# 1571   13.00            11
# 1572    7.00             6
#
# [1573 rows x 2 columns]

# %%
df.index % 2 == 0
# Out:
# array([ True, False,  True, ...,  True, False,  True])

# %%
# Extraer las filas pares de las columnas especificadas: "rating", "rating_count", "rating_five_count", "rating_four_count", "rating_three_count", "rating_two_count", "rating_one_count"
df.loc[df.index % 2 == 0, ["rating", "rating_count", "rating_five_count", "rating_four_count", "rating_three_count", "rating_two_count", "rating_one_count"]]
# Out:
#        rating  rating_count  rating_five_count  rating_four_count  \
# index
# 0        3.76            54               26.0                8.0
# 2        3.57            14                5.0                4.0
# 4        3.10            20                6.0                4.0
# 6        3.84          6742             3172.0             1352.0
# 8        3.47            15                6.0                2.0
# ...       ...           ...                ...                ...
# 1564     3.38           414              156.0               58.0
# 1566     3.54            28                7.0               11.0
# 1568     4.08          1367              722.0              293.0
# 1570     3.71            59               24.0               15.0
# 1572     4.07            14                8.0                3.0
#
#        rating_three_count  rating_two_count  rating_one_count
# index
# 0                    10.0               1.0               9.0
# ...

# %%
df.columns
# Out:
# Index(['title', 'title_orig', 'price', 'retail_price', 'currency_buyer',
#        'units_sold', 'uses_ad_boosts', 'rating', 'rating_count',
#        'rating_five_count', 'rating_four_count', 'rating_three_count',
#        'rating_two_count', 'rating_one_count', 'badges_count',
#        'badge_local_product', 'badge_product_quality', 'badge_fast_shipping',
#        'tags', 'product_color', 'product_variation_size_id',
#        'product_variation_inventory', 'shipping_option_name',
#        'shipping_option_price', 'shipping_is_express', 'countries_shipped_to',
#        'inventory_total', 'has_urgency_banner', 'urgency_text',
#        'origin_country', 'merchant_title', 'merchant_name',
#        'merchant_info_subtitle', 'merchant_rating_count', 'merchant_rating',
#        'merchant_id', 'merchant_has_profile_picture',
#        'merchant_profile_picture', 'product_url', 'product_picture',
#        'product_id', 'theme', 'crawl_month'],
#       dtype='object')

# %%
lista_cols = ['rating', 'rating_count',
       'rating_five_count', 'rating_four_count', 'rating_three_count',
       'rating_two_count', 'rating_one_count']

# %%
df.loc[::2, lista_cols]
# Out:
#        rating  rating_count  rating_five_count  rating_four_count  \
# index
# 0        3.76            54               26.0                8.0
# 2        3.57            14                5.0                4.0
# 4        3.10            20                6.0                4.0
# 6        3.84          6742             3172.0             1352.0
# 8        3.47            15                6.0                2.0
# ...       ...           ...                ...                ...
# 1564     3.38           414              156.0               58.0
# 1566     3.54            28                7.0               11.0
# 1568     4.08          1367              722.0              293.0
# 1570     3.71            59               24.0               15.0
# 1572     4.07            14                8.0                3.0
#
#        rating_three_count  rating_two_count  rating_one_count
# index
# 0                    10.0               1.0               9.0
# ...

# %%
df.loc[::2, 'rating':'rating_one_count']
# Out:
#        rating  rating_count  rating_five_count  rating_four_count  \
# index
# 0        3.76            54               26.0                8.0
# 2        3.57            14                5.0                4.0
# 4        3.10            20                6.0                4.0
# 6        3.84          6742             3172.0             1352.0
# 8        3.47            15                6.0                2.0
# ...       ...           ...                ...                ...
# 1564     3.38           414              156.0               58.0
# 1566     3.54            28                7.0               11.0
# 1568     4.08          1367              722.0              293.0
# 1570     3.71            59               24.0               15.0
# 1572     4.07            14                8.0                3.0
#
#        rating_three_count  rating_two_count  rating_one_count
# index
# 0                    10.0               1.0               9.0
# ...

# %%
list(df.columns)[14]
# Out:
# 'badges_count'

# %%
df.iloc[::2, 7:14]
# Out:
#        rating  rating_count  rating_five_count  rating_four_count  \
# index
# 0        3.76            54               26.0                8.0
# 2        3.57            14                5.0                4.0
# 4        3.10            20                6.0                4.0
# 6        3.84          6742             3172.0             1352.0
# 8        3.47            15                6.0                2.0
# ...       ...           ...                ...                ...
# 1564     3.38           414              156.0               58.0
# 1566     3.54            28                7.0               11.0
# 1568     4.08          1367              722.0              293.0
# 1570     3.71            59               24.0               15.0
# 1572     4.07            14                8.0                3.0
#
#        rating_three_count  rating_two_count  rating_one_count
# index
# 0                    10.0               1.0               9.0
# ...

# %%
df.loc[:4, 'rating':'rating_one_count']
# Out:
#        rating  rating_count  rating_five_count  rating_four_count  \
# index
# 0        3.76            54               26.0                8.0
# 1        3.45          6135             2269.0             1027.0
# 2        3.57            14                5.0                4.0
# 3        4.03           579              295.0              119.0
# 4        3.10            20                6.0                4.0
#
#        rating_three_count  rating_two_count  rating_one_count
# index
# 0                    10.0               1.0               9.0
# 1                  1118.0             644.0            1077.0
# 2                     2.0               0.0               3.0
# 3                    87.0              42.0              36.0
# 4                     2.0               2.0               6.0

# %%
df.iloc[:4, 7:14]
# Out:
#        rating  rating_count  rating_five_count  rating_four_count  \
# index
# 0        3.76            54               26.0                8.0
# 1        3.45          6135             2269.0             1027.0
# 2        3.57            14                5.0                4.0
# 3        4.03           579              295.0              119.0
#
#        rating_three_count  rating_two_count  rating_one_count
# index
# 0                    10.0               1.0               9.0
# 1                  1118.0             644.0            1077.0
# 2                     2.0               0.0               3.0
# 3                    87.0              42.0              36.0

# %%
df.iloc[:4, [7,8,9,10,11,12,13]]
# Out:
#        rating  rating_count  rating_five_count  rating_four_count  \
# index
# 0        3.76            54               26.0                8.0
# 1        3.45          6135             2269.0             1027.0
# 2        3.57            14                5.0                4.0
# 3        4.03           579              295.0              119.0
#
#        rating_three_count  rating_two_count  rating_one_count
# index
# 0                    10.0               1.0               9.0
# 1                  1118.0             644.0            1077.0
# 2                     2.0               0.0               3.0
# 3                    87.0              42.0              36.0

# %%
df.head(2)
# Out:
#                                                    title  \
# index
# 0      2020 Summer Vintage Flamingo Print  Pajamas Se...
# 1      SSHOUSE Summer Casual Sleeveless Soirée Party ...
#
#                                               title_orig  price  retail_price  \
# index
# 0      2020 Summer Vintage Flamingo Print  Pajamas Se...   16.0            14
# 1       Women's Casual Summer Sleeveless Sexy Mini Dress    8.0            22
#
#       currency_buyer  units_sold  uses_ad_boosts  rating  rating_count  \
# index
# 0                EUR         100               0    3.76            54
# 1                EUR       20000               1    3.45          6135
#
#        rating_five_count  ...  merchant_rating_count  merchant_rating  \
# index                     ...
# 0                   26.0  ...                    568         4.128521
# 1                 2269.0  ...                  17752         3.899673
#
#                     merchant_id  merchant_has_profile_picture  \
# ...

# %%
# encuentra las filas cuyo price sea superior a 12

df["price"] > 12
# Out:
# index
# 0        True
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1568    False
# 1569    False
# 1570    False
# 1571     True
# 1572    False
# Name: price, Length: 1573, dtype: bool

# %%
df.loc[[True, False, True, False]]

# %%
df.loc[df["price"] > 12, :].head(2)
# Out:
#                                                    title  \
# index
# 0      2020 Summer Vintage Flamingo Print  Pajamas Se...
# 30     HODMEXI Mode Amour Graffiti Imprimer Robe D'ét...
#
#                                               title_orig  price  retail_price  \
# index
# 0      2020 Summer Vintage Flamingo Print  Pajamas Se...   16.0            14
# 30     HODMEXI Fashion Love Graffiti Print Summer Dre...   14.0            76
#
#       currency_buyer  units_sold  uses_ad_boosts  rating  rating_count  \
# index
# 0                EUR         100               0    3.76            54
# 30               EUR         100               0    4.06            31
#
#        rating_five_count  ...  merchant_rating_count  merchant_rating  \
# index                     ...
# 0                   26.0  ...                    568         4.128521
# 30                  17.0  ...                  51369         3.968269
#
#                     merchant_id  merchant_has_profile_picture  \
# ...

# %%
df.iloc[list(df["price"] > 12), :].head(2)
# Out:
#                                                    title  \
# index
# 0      2020 Summer Vintage Flamingo Print  Pajamas Se...
# 30     HODMEXI Mode Amour Graffiti Imprimer Robe D'ét...
#
#                                               title_orig  price  retail_price  \
# index
# 0      2020 Summer Vintage Flamingo Print  Pajamas Se...   16.0            14
# 30     HODMEXI Fashion Love Graffiti Print Summer Dre...   14.0            76
#
#       currency_buyer  units_sold  uses_ad_boosts  rating  rating_count  \
# index
# 0                EUR         100               0    3.76            54
# 30               EUR         100               0    4.06            31
#
#        rating_five_count  ...  merchant_rating_count  merchant_rating  \
# index                     ...
# 0                   26.0  ...                    568         4.128521
# 30                  17.0  ...                  51369         3.968269
#
#                     merchant_id  merchant_has_profile_picture  \
# ...

# %%
df["total"] = df["price"] - df["retail_price"]

# %%
df.head()
# Out:
#                                                    title  \
# index
# 0      2020 Summer Vintage Flamingo Print  Pajamas Se...
# 1      SSHOUSE Summer Casual Sleeveless Soirée Party ...
# 2      2020 Nouvelle Arrivée Femmes Printemps et Été ...
# 3      Hot Summer Cool T-shirt pour les femmes Mode T...
# 4      Femmes Shorts d'été à lacets taille élastique ...
#
#                                               title_orig  price  retail_price  \
# index
# 0      2020 Summer Vintage Flamingo Print  Pajamas Se...  16.00            14
# 1       Women's Casual Summer Sleeveless Sexy Mini Dress   8.00            22
# 2      2020 New Arrival Women Spring and Summer Beach...   8.00            43
# 3      Hot Summer Cool T Shirt for Women Fashion Tops...   8.00             8
# 4      Women Summer Shorts Lace Up Elastic Waistband ...   2.72             3
#
#       currency_buyer  units_sold  uses_ad_boosts  rating  rating_count  \
# index
# ...

# %%
df.insert(2, "total_2", (df["price"] - df["retail_price"]))

# %%
df.head()
# Out:
#                                                    title  \
# index
# 0      2020 Summer Vintage Flamingo Print  Pajamas Se...
# 1      SSHOUSE Summer Casual Sleeveless Soirée Party ...
# 2      2020 Nouvelle Arrivée Femmes Printemps et Été ...
# 3      Hot Summer Cool T-shirt pour les femmes Mode T...
# 4      Femmes Shorts d'été à lacets taille élastique ...
#
#                                               title_orig  total_2  price  \
# index
# 0      2020 Summer Vintage Flamingo Print  Pajamas Se...     2.00  16.00
# 1       Women's Casual Summer Sleeveless Sexy Mini Dress   -14.00   8.00
# 2      2020 New Arrival Women Spring and Summer Beach...   -35.00   8.00
# 3      Hot Summer Cool T Shirt for Women Fashion Tops...     0.00   8.00
# 4      Women Summer Shorts Lace Up Elastic Waistband ...    -0.28   2.72
#
#        retail_price currency_buyer  units_sold  uses_ad_boosts  rating  \
# index
# 0                14            EUR         100               0    3.76
# ...
